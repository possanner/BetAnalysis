# %%
import numpy as np
import matplotlib.pyplot as plt

def redpr(str):
    print('\x1b[31m' + str + '\x1b[0m')

# %%
lines = np.arange(-16, 16.1, .5)
siz = len(lines)
data_all = np.zeros((siz, 6))
data_all[:, 0] = lines

conv_kernel = 2

leagues = ['NFL2016bis', 'NFL2017bis', 'NFL2018bis']
start_week = [5, 5, 5]
end_week = [17, 17, 17]

# %%
k = 0
print('In what follows y denotes the spread:')
for l in leagues:
    print()
    print('### league:', l)
    data = np.zeros((siz, 6))
    data[:, 0] = lines
    
    for wk in range(start_week[k], end_week[k] + 1):
        print('week:', wk)
        f = open(l + '/Week' + str(wk) + '/Results_w' + str(wk) + '.txt')
        Results = list(f)
        g = open(l + '/Week' + str(wk) + '/Lines_w' + str(wk) + '.txt')
        Lines = list(g)

        for i in range(len(Results)):
            
            j1 = Results[i].index(',')
            j2 = Results[i].index(',', j1 + 1)
            j3 = Results[i].index(',', j2 + 1)
            j4 = Results[i].index(',', j3 + 1)
            j5 = Results[i].index(',', j4 + 1)
            j6 = Results[i].index(',', j5 + 1)
            j7 = Results[i].index(',', j6 + 1)

            team1 = Results[i][j3 + 1:j4]
            score1 = int(Results[i][j6 + 1:j7].rstrip().lstrip())
            field = Results[i][j4 + 1:j5]
            team2 = Results[i][j5 + 1:j6]
            score2 = int(Results[i][j7 + 1:].rstrip().lstrip())
            if field=='':
                score_away = score2
                score_home = score1
            elif field=='@':
                score_away = score1
                score_home = score2
            else:
                print('error, no home field')
            
            #print(i, score_home, score_away)
            
            line = float(Lines[i][0:5])
            #print(home, away, line1, line2)
            ind = lines == line
            #print(ind)
            data[ind, 1] += 1.
            data_all[ind, 1] += 1.
            if score_away - score_home > 0:
                data[ind, 2] += 1.
                data_all[ind, 2] += 1.
            elif score_away - score_home < 0:
                data[ind, 4] += 1.
                data_all[ind, 4] += 1.
            else:
                data[ind, 3] += 1.
                data_all[ind, 3] += 1.
            data[ind, 5] += score_away - score_home
            data_all[ind, 5] += score_away - score_home
        
        #print('data:')
        #print(data)
        #print()
        #print('data_all:')
        #print(data_all)
        #print()

        f.close()
        g.close()
        
    k += 1
    
print()
print('### TOTAL:')

# one bin:
games = np.sum(data_all[:, 1])
wins = np.sum(data_all[:, 2])
ties = np.sum(data_all[:, 3])
losses = np.sum(data_all[:, 4])
diff = np.sum(data_all[:, 5])
print()
print('1 bin:')
print()
redpr('{:3d}'.format(-20) + '<= y <' + '{:3d}'.format(20) + ':  d.pts: {0:5.0f}    win: {1:5.0f}   X: {2:5.0f}   loss: {3:5.0f}   avg. margin {4:5.1f}'.format(games, wins, ties, losses, diff/games))
print('               percentages     win: {1:5.2f}   X: {2:5.2f}   loss: {3:5.2f}'.format(games, wins/games, ties/games, losses/games))
redpr('               odds            win: {1:5.2f}   X: {2:5.2f}   loss: {3:5.2f}'.format(games, games/wins, games/ties, games/losses))
    
# twenty bin:
print()
print('all bins:')
for i in range(conv_kernel, len(lines) - conv_kernel):
    #print('i', i, i - conv_kernel, i + conv_kernel)
    games = np.sum(data_all[i - conv_kernel:i + conv_kernel, 1])
    wins = np.sum(data_all[i - conv_kernel:i + conv_kernel, 2])
    ties = np.sum(data_all[i - conv_kernel:i + conv_kernel, 3])
    losses = np.sum(data_all[i - conv_kernel:i + conv_kernel, 4])
    diff = np.sum(data_all[i - conv_kernel:i + conv_kernel, 5])
    
    print()
    redpr('{:5.1f}'.format(lines[i]) + ':  d.pts: {0:5.0f}    win: {1:5.0f}   X: {2:5.0f}   loss: {3:5.0f}   avg. margin {4:5.1f}'.format(games, wins, ties, losses, diff/games))
    print('                     percentages     win: {1:5.2f}   X: {2:5.2f}   loss: {3:5.2f}'.format(games, wins/games, ties/games, losses/games))
    redpr('                     odds            win: {1:5.2f}   X: {2:5.2f}   loss: {3:5.2f}'.format(games, games/wins, games/ties, games/losses))

# all bins:
#print('All bins:')
#for i in range(len(lines)):
#    games = np.sum(data_all[i:i + 1, 1])
#    wins = np.sum(data_all[i:i + 1, 2])
#    ties = np.sum(data_all[i:i + 1, 3])
#    losses = np.sum(data_all[i:i + 1, 4])
#    print()
#    redpr('y = {:5.1f}'.format(lines[i]) + ':  d.pts: {0:5.0f}    win: {1:5.0f}   X: {2:5.0f}   loss: {3:5.0f}'.format(games, wins, ties, losses))
#    print('               percentages     win: {1:5.2f}   X: {2:5.2f}   loss: {3:5.2f}'.format(games, wins/games, ties/games, losses/games))
#    redpr('               odds            win: {1:5.2f}   X: {2:5.2f}   loss: {3:5.2f}'.format(games, games/wins, games/ties, games/losses))
# Out:
# In what follows y denotes the spread:
#
# ### league: NFL2016bis
# week: 5
# week: 6
# week: 7
# week: 8
# week: 9
# week: 10
# week: 11
# week: 12
# week: 13
# week: 14
# week: 15
# week: 16
# week: 17
#
# ### league: NFL2017bis
# week: 5
# week: 6
# week: 7
# week: 8
# week: 9
# week: 10
# week: 11
# week: 12
# week: 13
# week: 14
# week: 15
# week: 16
# week: 17
#
# ### league: NFL2018bis
# week: 5
# week: 6
# week: 7
# week: 8
# week: 9
# week: 10
# week: 11
# week: 12
# week: 13
# week: 14
# week: 15
# week: 16
# week: 17
#
# ### TOTAL:
#
# 1 bin:
#
# -20<= y < 20:  d.pts:   579    win:   239   X:     2   loss:   338   avg. margin  -2.2
#                percentages     win:  0.41   X:  0.00   loss:  0.58
#                odds            win:  2.42   X: 289.50   loss:  1.71
#
# all bins:
#
# -15.0:  d.pts:     0    win:     0   X:     0   loss:     0   avg. margin   nan
#                      percentages     win:   nan   X:   nan   loss:   nan
#                      odds            win:   nan   X:   nan   loss:   nan
#
# -14.5:  d.pts:     0    win:     0   X:     0   loss:     0   avg. margin   nan
#                      percentages     win:   nan   X:   nan   loss:   nan
#                      odds            win:   nan   X:   nan   loss:   nan
#
# -14.0:  d.pts:     0    win:     0   X:     0   loss:     0   avg. margin   nan
#                      percentages     win:   nan   X:   nan   loss:   nan
#                      odds            win:   nan   X:   nan   loss:   nan
#
# -13.5:  d.pts:     0    win:     0   X:     0   loss:     0   avg. margin   nan
#                      percentages     win:   nan   X:   nan   loss:   nan
#                      odds            win:   nan   X:   nan   loss:   nan
#
# -13.0:  d.pts:     0    win:     0   X:     0   loss:     0   avg. margin   nan
#                      percentages     win:   nan   X:   nan   loss:   nan
#                      odds            win:   nan   X:   nan   loss:   nan
#
# -12.5:  d.pts:     0    win:     0   X:     0   loss:     0   avg. margin   nan
#                      percentages     win:   nan   X:   nan   loss:   nan
#                      odds            win:   nan   X:   nan   loss:   nan
#
# -12.0:  d.pts:     0    win:     0   X:     0   loss:     0   avg. margin   nan
#                      percentages     win:   nan   X:   nan   loss:   nan
#                      odds            win:   nan   X:   nan   loss:   nan
#
# -11.5:  d.pts:     0    win:     0   X:     0   loss:     0   avg. margin   nan
#                      percentages     win:   nan   X:   nan   loss:   nan
#                      odds            win:   nan   X:   nan   loss:   nan
#
# -11.0:  d.pts:     0    win:     0   X:     0   loss:     0   avg. margin   nan
#                      percentages     win:   nan   X:   nan   loss:   nan
#                      odds            win:   nan   X:   nan   loss:   nan
#
# -10.5:  d.pts:     0    win:     0   X:     0   loss:     0   avg. margin   nan
#                      percentages     win:   nan   X:   nan   loss:   nan
#                      odds            win:   nan   X:   nan   loss:   nan
#
# -10.0:  d.pts:     0    win:     0   X:     0   loss:     0   avg. margin   nan
#                      percentages     win:   nan   X:   nan   loss:   nan
#                      odds            win:   nan   X:   nan   loss:   nan
#
#  -9.5:  d.pts:     0    win:     0   X:     0   loss:     0   avg. margin   nan
#                      percentages     win:   nan   X:   nan   loss:   nan
#                      odds            win:   nan   X:   nan   loss:   nan
#
#  -9.0:  d.pts:     0    win:     0   X:     0   loss:     0   avg. margin   nan
#                      percentages     win:   nan   X:   nan   loss:   nan
#                      odds            win:   nan   X:   nan   loss:   nan
#
#  -8.5:  d.pts:     0    win:     0   X:     0   loss:     0   avg. margin   nan
#                      percentages     win:   nan   X:   nan   loss:   nan
#                      odds            win:   nan   X:   nan   loss:   nan
#
#  -8.0:  d.pts:     0    win:     0   X:     0   loss:     0   avg. margin   nan
#                      percentages     win:   nan   X:   nan   loss:   nan
#                      odds            win:   nan   X:   nan   loss:   nan
#
#  -7.5:  d.pts:     0    win:     0   X:     0   loss:     0   avg. margin   nan
#                      percentages     win:   nan   X:   nan   loss:   nan
#                      odds            win:   nan   X:   nan   loss:   nan
#
#  -7.0:  d.pts:     2    win:     2   X:     0   loss:     0   avg. margin   8.5
#                      percentages     win:  1.00   X:  0.00   loss:  0.00
#                      odds            win:  1.00   X:   inf   loss:   inf
#
#  -6.5:  d.pts:     2    win:     2   X:     0   loss:     0   avg. margin   8.5
#                      percentages     win:  1.00   X:  0.00   loss:  0.00
#                      odds            win:  1.00   X:   inf   loss:   inf
#
#  -6.0:  d.pts:     4    win:     3   X:     0   loss:     1   avg. margin  10.0
#                      percentages     win:  0.75   X:  0.00   loss:  0.25
#                      odds            win:  1.33   X:   inf   loss:  4.00
#
#  -5.5:  d.pts:     9    win:     6   X:     0   loss:     3   avg. margin  10.4
#                      percentages     win:  0.67   X:  0.00   loss:  0.33
#                      odds            win:  1.50   X:   inf   loss:  3.00
#
#  -5.0:  d.pts:     8    win:     5   X:     0   loss:     3   avg. margin  10.5
#                      percentages     win:  0.62   X:  0.00   loss:  0.38
#                      odds            win:  1.60   X:   inf   loss:  2.67
#
#  -4.5:  d.pts:    10    win:     6   X:     0   loss:     4   avg. margin   9.5
#                      percentages     win:  0.60   X:  0.00   loss:  0.40
#                      odds            win:  1.67   X:   inf   loss:  2.50
#
#  -4.0:  d.pts:    10    win:     7   X:     0   loss:     3   avg. margin  10.7
#                      percentages     win:  0.70   X:  0.00   loss:  0.30
#                      odds            win:  1.43   X:   inf   loss:  3.33
#
#  -3.5:  d.pts:    14    win:    11   X:     0   loss:     3   avg. margin  11.1
#                      percentages     win:  0.79   X:  0.00   loss:  0.21
#                      odds            win:  1.27   X:   inf   loss:  4.67
#
#  -3.0:  d.pts:    17    win:    13   X:     0   loss:     4   avg. margin  11.4
#                      percentages     win:  0.76   X:  0.00   loss:  0.24
#                      odds            win:  1.31   X:   inf   loss:  4.25
#
#  -2.5:  d.pts:    23    win:    16   X:     0   loss:     7   avg. margin   9.3
#                      percentages     win:  0.70   X:  0.00   loss:  0.30
#                      odds            win:  1.44   X:   inf   loss:  3.29
#
#  -2.0:  d.pts:    31    win:    23   X:     0   loss:     8   avg. margin   8.4
#                      percentages     win:  0.74   X:  0.00   loss:  0.26
#                      odds            win:  1.35   X:   inf   loss:  3.88
#
#  -1.5:  d.pts:    30    win:    21   X:     0   loss:     9   avg. margin   8.2
#                      percentages     win:  0.70   X:  0.00   loss:  0.30
#                      odds            win:  1.43   X:   inf   loss:  3.33
#
#  -1.0:  d.pts:    47    win:    30   X:     0   loss:    17   avg. margin   5.5
#                      percentages     win:  0.64   X:  0.00   loss:  0.36
#                      odds            win:  1.57   X:   inf   loss:  2.76
#
#  -0.5:  d.pts:    63    win:    39   X:     0   loss:    24   avg. margin   4.5
#                      percentages     win:  0.62   X:  0.00   loss:  0.38
#                      odds            win:  1.62   X:   inf   loss:  2.62
#
#   0.0:  d.pts:    76    win:    41   X:     0   loss:    35   avg. margin   3.1
#                      percentages     win:  0.54   X:  0.00   loss:  0.46
#                      odds            win:  1.85   X:   inf   loss:  2.17
#
#   0.5:  d.pts:    96    win:    54   X:     0   loss:    42   avg. margin   2.8
#                      percentages     win:  0.56   X:  0.00   loss:  0.44
#                      odds            win:  1.78   X:   inf   loss:  2.29
#
#   1.0:  d.pts:    98    win:    57   X:     0   loss:    41   avg. margin   2.7
#                      percentages     win:  0.58   X:  0.00   loss:  0.42
#                      odds            win:  1.72   X:   inf   loss:  2.39
#
#   1.5:  d.pts:   113    win:    60   X:     0   loss:    53   avg. margin   1.9
#                      percentages     win:  0.53   X:  0.00   loss:  0.47
#                      odds            win:  1.88   X:   inf   loss:  2.13
#
#   2.0:  d.pts:   119    win:    65   X:     0   loss:    54   avg. margin   1.3
#                      percentages     win:  0.55   X:  0.00   loss:  0.45
#                      odds            win:  1.83   X:   inf   loss:  2.20
#
#   2.5:  d.pts:   117    win:    64   X:     0   loss:    53   avg. margin   0.9
#                      percentages     win:  0.55   X:  0.00   loss:  0.45
#                      odds            win:  1.83   X:   inf   loss:  2.21
#
#   3.0:  d.pts:   130    win:    66   X:     1   loss:    63   avg. margin  -0.1
#                      percentages     win:  0.51   X:  0.01   loss:  0.48
#                      odds            win:  1.97   X: 130.00   loss:  2.06
#
#   3.5:  d.pts:   127    win:    62   X:     1   loss:    64   avg. margin  -2.0
#                      percentages     win:  0.49   X:  0.01   loss:  0.50
#                      odds            win:  2.05   X: 127.00   loss:  1.98
#
#   4.0:  d.pts:   140    win:    55   X:     2   loss:    83   avg. margin  -3.6
#                      percentages     win:  0.39   X:  0.01   loss:  0.59
#                      odds            win:  2.55   X: 70.00   loss:  1.69
#
#   4.5:  d.pts:   142    win:    47   X:     2   loss:    93   avg. margin  -5.2
#                      percentages     win:  0.33   X:  0.01   loss:  0.65
#                      odds            win:  3.02   X: 71.00   loss:  1.53
#
#   5.0:  d.pts:   140    win:    37   X:     1   loss:   102   avg. margin  -6.9
#                      percentages     win:  0.26   X:  0.01   loss:  0.73
#                      odds            win:  3.78   X: 140.00   loss:  1.37
#
#   5.5:  d.pts:   127    win:    31   X:     1   loss:    95   avg. margin  -6.3
#                      percentages     win:  0.24   X:  0.01   loss:  0.75
#                      odds            win:  4.10   X: 127.00   loss:  1.34
#
#   6.0:  d.pts:   108    win:    26   X:     0   loss:    82   avg. margin  -6.4
#                      percentages     win:  0.24   X:  0.00   loss:  0.76
#                      odds            win:  4.15   X:   inf   loss:  1.32
#
#   6.5:  d.pts:   105    win:    23   X:     0   loss:    82   avg. margin  -7.6
#                      percentages     win:  0.22   X:  0.00   loss:  0.78
#                      odds            win:  4.57   X:   inf   loss:  1.28
#
#   7.0:  d.pts:    84    win:    21   X:     0   loss:    63   avg. margin  -6.3
#                      percentages     win:  0.25   X:  0.00   loss:  0.75
#                      odds            win:  4.00   X:   inf   loss:  1.33
#
#   7.5:  d.pts:    70    win:    16   X:     0   loss:    54   avg. margin  -8.3
#                      percentages     win:  0.23   X:  0.00   loss:  0.77
#                      odds            win:  4.38   X:   inf   loss:  1.30
#
#   8.0:  d.pts:    58    win:    16   X:     0   loss:    42   avg. margin  -8.3
#                      percentages     win:  0.28   X:  0.00   loss:  0.72
#                      odds            win:  3.62   X:   inf   loss:  1.38
#
#   8.5:  d.pts:    45    win:    11   X:     0   loss:    34   avg. margin  -8.7
#                      percentages     win:  0.24   X:  0.00   loss:  0.76
#                      odds            win:  4.09   X:   inf   loss:  1.32
#
#   9.0:  d.pts:    38    win:     6   X:     0   loss:    32   avg. margin -10.9
#                      percentages     win:  0.16   X:  0.00   loss:  0.84
#                      odds            win:  6.33   X:   inf   loss:  1.19
#
#   9.5:  d.pts:    32    win:     5   X:     0   loss:    27   avg. margin -10.8
#                      percentages     win:  0.16   X:  0.00   loss:  0.84
#                      odds            win:  6.40   X:   inf   loss:  1.19
#
#  10.0:  d.pts:    27    win:     1   X:     0   loss:    26   avg. margin -13.3
#                      percentages     win:  0.04   X:  0.00   loss:  0.96
#                      odds            win: 27.00   X:   inf   loss:  1.04
#
#  10.5:  d.pts:    16    win:     1   X:     0   loss:    15   avg. margin -11.7
#                      percentages     win:  0.06   X:  0.00   loss:  0.94
#                      odds            win: 16.00   X:   inf   loss:  1.07
#
#  11.0:  d.pts:    13    win:     2   X:     0   loss:    11   avg. margin -12.3
#                      percentages     win:  0.15   X:  0.00   loss:  0.85
#                      odds            win:  6.50   X:   inf   loss:  1.18
#
#  11.5:  d.pts:    10    win:     2   X:     0   loss:     8   avg. margin -11.8
#                      percentages     win:  0.20   X:  0.00   loss:  0.80
#                      odds            win:  5.00   X:   inf   loss:  1.25
#
#  12.0:  d.pts:     4    win:     2   X:     0   loss:     2   avg. margin  -7.0
#                      percentages     win:  0.50   X:  0.00   loss:  0.50
#                      odds            win:  2.00   X:   inf   loss:  2.00
#
#  12.5:  d.pts:     4    win:     1   X:     0   loss:     3   avg. margin -10.8
#                      percentages     win:  0.25   X:  0.00   loss:  0.75
#                      odds            win:  4.00   X:   inf   loss:  1.33
#
#  13.0:  d.pts:     2    win:     0   X:     0   loss:     2   avg. margin  -7.5
#                      percentages     win:  0.00   X:  0.00   loss:  1.00
#                      odds            win:   inf   X:   inf   loss:  1.00
#
#  13.5:  d.pts:     2    win:     0   X:     0   loss:     2   avg. margin  -7.5
#                      percentages     win:  0.00   X:  0.00   loss:  1.00
#                      odds            win:   inf   X:   inf   loss:  1.00
#
#  14.0:  d.pts:     2    win:     0   X:     0   loss:     2   avg. margin  -7.5
#                      percentages     win:  0.00   X:  0.00   loss:  1.00
#                      odds            win:   inf   X:   inf   loss:  1.00
#
#  14.5:  d.pts:     1    win:     0   X:     0   loss:     1   avg. margin  -3.0
#                      percentages     win:  0.00   X:  0.00   loss:  1.00
#                      odds            win:   inf   X:   inf   loss:  1.00
#
#  15.0:  d.pts:     0    win:     0   X:     0   loss:     0   avg. margin   nan
#                      percentages     win:   nan   X:   nan   loss:   nan
#                      odds            win:   nan   X:   nan   loss:   nan
# /Users/possanner/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:100: RuntimeWarning: invalid value encountered in double_scalars
# /Users/possanner/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:101: RuntimeWarning: invalid value encountered in double_scalars
# /Users/possanner/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:102: RuntimeWarning: invalid value encountered in double_scalars
# /Users/possanner/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:102: RuntimeWarning: divide by zero encountered in double_scalars

# %%
data_all
# Out:
# array([[ -16. ,    0. ,    0. ,    0. ,    0. ,    0. ],
#        [ -15.5,    0. ,    0. ,    0. ,    0. ,    0. ],
#        [ -15. ,    0. ,    0. ,    0. ,    0. ,    0. ],
#        [ -14.5,    0. ,    0. ,    0. ,    0. ,    0. ],
#        [ -14. ,    0. ,    0. ,    0. ,    0. ,    0. ],
#        [ -13.5,    0. ,    0. ,    0. ,    0. ,    0. ],
#        [ -13. ,    0. ,    0. ,    0. ,    0. ,    0. ],
#        [ -12.5,    0. ,    0. ,    0. ,    0. ,    0. ],
#        [ -12. ,    0. ,    0. ,    0. ,    0. ,    0. ],
#        [ -11.5,    0. ,    0. ,    0. ,    0. ,    0. ],
#        [ -11. ,    0. ,    0. ,    0. ,    0. ,    0. ],
#        [ -10.5,    0. ,    0. ,    0. ,    0. ,    0. ],
#        [ -10. ,    0. ,    0. ,    0. ,    0. ,    0. ],
#        [  -9.5,    0. ,    0. ,    0. ,    0. ,    0. ],
#        [  -9. ,    0. ,    0. ,    0. ,    0. ,    0. ],
#        [  -8.5,    0. ,    0. ,    0. ,    0. ,    0. ],
#        [  -8. ,    0. ,    0. ,    0. ,    0. ,    0. ],
#        [  -7.5,    0. ,    0. ,    0. ,    0. ,    0. ],
#        [  -7. ,    0. ,    0. ,    0. ,    0. ,    0. ],
#        [  -6.5,    2. ,    2. ,    0. ,    0. ,   17. ],
#        [  -6. ,    0. ,    0. ,    0. ,    0. ,    0. ],
#        [  -5.5,    2. ,    1. ,    0. ,    1. ,   23. ],
#        [  -5. ,    5. ,    3. ,    0. ,    2. ,   54. ],
#        [  -4.5,    1. ,    1. ,    0. ,    0. ,    7. ],
#        [  -4. ,    2. ,    1. ,    0. ,    1. ,   11. ],
#        [  -3.5,    2. ,    2. ,    0. ,    0. ,   35. ],
#        [  -3. ,    9. ,    7. ,    0. ,    2. ,  103. ],
#        [  -2.5,    4. ,    3. ,    0. ,    1. ,   44. ],
#        [  -2. ,    8. ,    4. ,    0. ,    4. ,   32. ],
#        [  -1.5,   10. ,    9. ,    0. ,    1. ,   82. ],
#        [  -1. ,    8. ,    5. ,    0. ,    3. ,   88. ],
#        [  -0.5,   21. ,   12. ,    0. ,    9. ,   57. ],
#        [   0. ,   24. ,   13. ,    0. ,   11. ,   54. ],
#        [   0.5,   23. ,   11. ,    0. ,   12. ,   38. ],
#        [   1. ,   28. ,   18. ,    0. ,   10. ,  122. ],
#        [   1.5,   23. ,   15. ,    0. ,    8. ,   54. ],
#        [   2. ,   39. ,   16. ,    0. ,   23. ,   -1. ],
#        [   2.5,   29. ,   16. ,    0. ,   13. ,  -23. ],
#        [   3. ,   26. ,   17. ,    0. ,    9. ,   80. ],
#        [   3.5,   36. ,   17. ,    1. ,   18. ,  -70. ],
#        [   4. ,   36. ,   12. ,    0. ,   24. , -235. ],
#        [   4.5,   42. ,    9. ,    1. ,   32. , -285. ],
#        [   5. ,   28. ,    9. ,    0. ,   19. , -144. ],
#        [   5.5,   34. ,    7. ,    0. ,   27. , -305. ],
#        [   6. ,   23. ,    6. ,    0. ,   17. ,  -64. ],
#        [   6.5,   23. ,    4. ,    0. ,   19. , -174. ],
#        [   7. ,   25. ,    6. ,    0. ,   19. , -260. ],
#        [   7.5,   13. ,    5. ,    0. ,    8. ,  -34. ],
#        [   8. ,    9. ,    1. ,    0. ,    8. , -111. ],
#        [   8.5,   11. ,    4. ,    0. ,    7. ,  -77. ],
#        [   9. ,   12. ,    1. ,    0. ,   11. , -170. ],
#        [   9.5,    6. ,    0. ,    0. ,    6. ,  -58. ],
#        [  10. ,    3. ,    0. ,    0. ,    3. ,  -42. ],
#        [  10.5,    6. ,    0. ,    0. ,    6. ,  -90. ],
#        [  11. ,    1. ,    1. ,    0. ,    0. ,    3. ],
#        [  11.5,    3. ,    1. ,    0. ,    2. ,  -31. ],
#        [  12. ,    0. ,    0. ,    0. ,    0. ,    0. ],
#        [  12.5,    0. ,    0. ,    0. ,    0. ,    0. ],
#        [  13. ,    1. ,    0. ,    0. ,    1. ,  -12. ],
#        [  13.5,    1. ,    0. ,    0. ,    1. ,   -3. ],
#        [  14. ,    0. ,    0. ,    0. ,    0. ,    0. ],
#        [  14.5,    0. ,    0. ,    0. ,    0. ,    0. ],
#        [  15. ,    0. ,    0. ,    0. ,    0. ,    0. ],
#        [  15.5,    0. ,    0. ,    0. ,    0. ,    0. ],
#        [  16. ,    0. ,    0. ,    0. ,    0. ,    0. ]])

# %%
score_away
# Out:
# 33
