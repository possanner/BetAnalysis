# %%
import numpy as np
import matplotlib.pyplot as plt

def redpr(str):
    print('\x1b[31m' + str + '\x1b[0m')

# %%
lines = np.arange(-20, 20.1, .5)
siz = len(lines)
data_all = np.zeros((siz, 7))
data_all[:, 0] = lines

bins1 = [0.0]
edges1 = [-20, 20]

bins10 = [-30, -18, -6, 6, 18, 30]
edges10 = np.arange(-20, 22, 4)

bins20 = [-30, -18, -6, 6, 18, 30]
edges20 = [-20, -10,  -7, -5, -3, -1,  1.5, 
           3.5, 5.5, 7.5, 10.5, 20]
bins40 = [-30, -18, -6, 6, 18, 30]
edges40 = np.arange(-20, 21)

leagues = ['NFL2016bis', 'NFL2017bis']
start_week = [3, 3]
end_week = [17, 17]

# %%
edges20
# Out:
# [-20, -10, -7, -5, -3, -1, 1.5, 3.5, 5.5, 7.5, 10.5, 20]

# %%
k = 0
print('In what follows y denotes the spread:')
for l in leagues:
    print()
    print('### league:', l)
    data = np.zeros((siz, 7))
    data[:, 0] = lines
    
    for wk in range(start_week[k], end_week[k] + 1):
        print('week:', wk)
        f = open(l + '/Week' + str(wk) + '/Results_w' + str(wk) + '.txt')
        Results = list(f)
        g = open(l + '/Week' + str(wk) + '/Lines_w' + str(wk) + '.txt')
        Lines = list(g)

        for i in range(len(Results)):
            
            j1 = Results[i].index(',')
            j2 = Results[i].index(',', j1 + 1)
            j3 = Results[i].index(',', j2 + 1)
            j4 = Results[i].index(',', j3 + 1)
            j5 = Results[i].index(',', j4 + 1)
            j6 = Results[i].index(',', j5 + 1)
            j7 = Results[i].index(',', j6 + 1)

            team1 = Results[i][j3 + 1:j4]
            score1 = int(Results[i][j6 + 1:j7].rstrip().lstrip())
            field = Results[i][j4 + 1:j5]
            team2 = Results[i][j5 + 1:j6]
            score2 = int(Results[i][j7 + 1:].rstrip().lstrip())
            if field=='':
                score_away = score2
                score_home = score1
            elif field=='@':
                score_away = score1
                score_home = score2
            else:
                print('error, no home field')
            
            #print(i, score_home, score_away)
            
            line = float(Lines[i][0:5])
            #print(home, away, line1, line2)
            ind = lines == line
            #print(ind)
            data[ind, 1] += 1.
            data_all[ind, 1] += 1.
            if score_away - score_home > 0:
                data[ind, 2] += 1.
                data_all[ind, 2] += 1.
            elif score_away - score_home < 0:
                data[ind, 4] += 1.
                data_all[ind, 4] += 1.
            else:
                data[ind, 3] += 1.
                data_all[ind, 3] += 1.
        
        #print('data:')
        #print(data)
        #print()
        #print('data_all:')
        #print(data_all)
        #print()

        f.close()
        g.close()
    
    if False:
        # one bin:
        ind = np.arange(2)
        ind[0] = np.where(lines == edges1[0])[0][0]
        ind[1] = np.where(lines == edges1[1])[0][0]
        games = np.sum(data[ind[0]:ind[1], 1])
        wins = np.sum(data[ind[0]:ind[1], 2])
        ties = np.sum(data[ind[0]:ind[1], 3])
        losses = np.sum(data[ind[0]:ind[1], 4])
        margin2 = np.sum(data[ind[0]:ind[1], 5])
        margin3 = np.sum(data[ind[0]:ind[1], 6])
        print()
        print('1 bin:')
        print()
        print('{:3d}'.format(-40) + '<= y <' + '{:3d}'.format(40) + ':  d.pts: {0:5.0f}    win: {1:5.0f}   X: {2:5.0f}   loss: {3:5.0f}'.format(games, wins, ties, losses))
        print('               percentages     win: {1:5.2f}   X: {2:5.2f}   loss: {3:5.2f}   1X: {4:5.2f}   X2: {5:5.2f}'.format(games, wins/games, ties/games, losses/games, (wins + ties)/games, (losses + ties)/games))
        print('               odds            win: {1:5.2f}   X: {2:5.2f}   loss: {3:5.2f}   1X: {4:5.2f}   X2: {5:5.2f}'.format(games, games/wins, games/ties, games/losses, games/(wins + ties), games/(losses + ties)))
        print('       >=2 goals difference in win: {0:5.0f}  percentage: {1:5.2f}  odds: {2:5.2f}'.format(margin2, margin2/games, games/margin2))
        print('       >=3 goals difference in win: {0:5.0f}  percentage: {1:5.2f}  odds: {2:5.2f}'.format(margin3, margin3/games, games/margin3))

        # seven bins:
        ind = np.arange(8)
        ind[0] = np.where(lines == edges7[0])[0][0]
        ind[1] = np.where(lines == edges7[1])[0][0]
        ind[2] = np.where(lines == edges7[2])[0][0]
        ind[3] = np.where(lines == edges7[3])[0][0]
        ind[4] = np.where(lines == edges7[4])[0][0]
        ind[5] = np.where(lines == edges7[5])[0][0]
        ind[6] = np.where(lines == edges7[6])[0][0]
        ind[7] = np.where(lines == edges7[7])[0][0]
        #print(ind)
        print()
        print('7 bins:')
        for i in range(len(ind) - 1):
            games = np.sum(data[ind[i]:ind[i + 1], 1])
            wins = np.sum(data[ind[i]:ind[i + 1], 2])
            ties = np.sum(data[ind[i]:ind[i + 1], 3])
            losses = np.sum(data[ind[i]:ind[i + 1], 4])
            margin2 = np.sum(data[ind[i]:ind[i + 1], 5])
            margin3 = np.sum(data[ind[i]:ind[i + 1], 6])
            print()
            redpr('{:3d}'.format(lines[ind[i]]) + '<= y <' + '{:3d}'.format(lines[ind[i + 1]]) + ':  d.pts: {0:5.0f}    win: {1:5.0f}   X: {2:5.0f}   loss: {3:5.0f}'.format(games, wins, ties, losses))
            print('               percentages     win: {1:5.2f}   X: {2:5.2f}   loss: {3:5.2f}   1X: {4:5.2f}   X2: {5:5.2f}'.format(games, wins/games, ties/games, losses/games, (wins + ties)/games, (losses + ties)/games))
            redpr('               odds            win: {1:5.2f}   X: {2:5.2f}   loss: {3:5.2f}   1X: {4:5.2f}   X2: {5:5.2f}'.format(games, games/wins, games/ties, games/losses, games/(wins + ties), games/(losses + ties)))
            print('       >=2 goals difference in win: {0:5.0f}  percentage: {1:5.2f}  odds: {2:5.2f}'.format(margin2, margin2/games, games/margin2))
            print('       >=3 goals difference in win: {0:5.0f}  percentage: {1:5.2f}  odds: {2:5.2f}'.format(margin3, margin3/games, games/margin3))
    
    k += 1
    
print()
print('### TOTAL:')

# one bin:
ind = np.arange(2)
ind[0] = np.where(lines == edges1[0])[0][0]
ind[1] = np.where(lines == edges1[1])[0][0]
games = np.sum(data_all[ind[0]:ind[1], 1])
wins = np.sum(data_all[ind[0]:ind[1], 2])
ties = np.sum(data_all[ind[0]:ind[1], 3])
losses = np.sum(data_all[ind[0]:ind[1], 4])
print()
print('1 bin:')
print()
redpr('{:3d}'.format(-20) + '<= y <' + '{:3d}'.format(20) + ':  d.pts: {0:5.0f}    win: {1:5.0f}   X: {2:5.0f}   loss: {3:5.0f}'.format(games, wins, ties, losses))
print('               percentages     win: {1:5.2f}   X: {2:5.2f}   loss: {3:5.2f}'.format(games, wins/games, ties/games, losses/games))
redpr('               odds            win: {1:5.2f}   X: {2:5.2f}   loss: {3:5.2f}'.format(games, games/wins, games/ties, games/losses))
    
# twenty bin:
ind = np.arange(len(edges20))
for i in range(len(edges20)):
    ind[i] = np.where(lines == edges20[i])[0][0]

print()
print('20 bins:')
for i in range(len(ind) - 1):
    games = np.sum(data_all[ind[i]:ind[i + 1], 1])
    wins = np.sum(data_all[ind[i]:ind[i + 1], 2])
    ties = np.sum(data_all[ind[i]:ind[i + 1], 3])
    losses = np.sum(data_all[ind[i]:ind[i + 1], 4])
    
    print()
    redpr('{:5.1f}'.format(lines[ind[i]]) + ' <= y < ' + '{:5.1f}'.format(lines[ind[i + 1]]) + ':  d.pts: {0:5.0f}    win: {1:5.0f}   X: {2:5.0f}   loss: {3:5.0f}'.format(games, wins, ties, losses))
    print('                     percentages     win: {1:5.2f}   X: {2:5.2f}   loss: {3:5.2f}'.format(games, wins/games, ties/games, losses/games))
    redpr('                     odds            win: {1:5.2f}   X: {2:5.2f}   loss: {3:5.2f}'.format(games, games/wins, games/ties, games/losses))

# all bins:
#print('All bins:')
#for i in range(len(lines)):
#    games = np.sum(data_all[i:i + 1, 1])
#    wins = np.sum(data_all[i:i + 1, 2])
#    ties = np.sum(data_all[i:i + 1, 3])
#    losses = np.sum(data_all[i:i + 1, 4])
#    print()
#    redpr('y = {:5.1f}'.format(lines[i]) + ':  d.pts: {0:5.0f}    win: {1:5.0f}   X: {2:5.0f}   loss: {3:5.0f}'.format(games, wins, ties, losses))
#    print('               percentages     win: {1:5.2f}   X: {2:5.2f}   loss: {3:5.2f}'.format(games, wins/games, ties/games, losses/games))
#    redpr('               odds            win: {1:5.2f}   X: {2:5.2f}   loss: {3:5.2f}'.format(games, games/wins, games/ties, games/losses))
# Out:
# In what follows y denotes the spread:
#
# ### league: NFL2016bis
# week: 3
# week: 4
# week: 5
# week: 6
# week: 7
# week: 8
# week: 9
# week: 10
# week: 11
# week: 12
# week: 13
# week: 14
# week: 15
# week: 16
# week: 17
#
# ### league: NFL2017bis
# week: 3
# week: 4
# week: 5
# week: 6
# week: 7
# week: 8
# week: 9
# week: 10
# week: 11
# week: 12
# week: 13
# week: 14
# week: 15
# week: 16
# week: 17
#
# ### TOTAL:
#
# 1 bin:
#
# -20<= y < 20:  d.pts:   449    win:   188   X:     2   loss:   259
#                percentages     win:  0.42   X:  0.00   loss:  0.58
#                odds            win:  2.39   X: 224.50   loss:  1.73
#
# 20 bins:
#
# -20.0 <= y < -10.0:  d.pts:     0    win:     0   X:     0   loss:     0
#                      percentages     win:   nan   X:   nan   loss:   nan
#                      odds            win:   nan   X:   nan   loss:   nan
#
# -10.0 <= y <  -7.0:  d.pts:     0    win:     0   X:     0   loss:     0
#                      percentages     win:   nan   X:   nan   loss:   nan
#                      odds            win:   nan   X:   nan   loss:   nan
#
#  -7.0 <= y <  -5.0:  d.pts:     4    win:     3   X:     0   loss:     1
#                      percentages     win:  0.75   X:  0.00   loss:  0.25
#                      odds            win:  1.33   X:   inf   loss:  4.00
#
#  -5.0 <= y <  -3.0:  d.pts:     5    win:     3   X:     0   loss:     2
#                      percentages     win:  0.60   X:  0.00   loss:  0.40
#                      odds            win:  1.67   X:   inf   loss:  2.50
#
#  -3.0 <= y <  -1.0:  d.pts:    23    win:    16   X:     0   loss:     7
#                      percentages     win:  0.70   X:  0.00   loss:  0.30
#                      odds            win:  1.44   X:   inf   loss:  3.29
#
#  -1.0 <= y <   1.5:  d.pts:    79    win:    40   X:     0   loss:    39
#                      percentages     win:  0.51   X:  0.00   loss:  0.49
#                      odds            win:  1.98   X:   inf   loss:  2.03
#
#   1.5 <= y <   3.5:  d.pts:    97    win:    56   X:     0   loss:    41
#                      percentages     win:  0.58   X:  0.00   loss:  0.42
#                      odds            win:  1.73   X:   inf   loss:  2.37
#
#   3.5 <= y <   5.5:  d.pts:   116    win:    41   X:     2   loss:    73
#                      percentages     win:  0.35   X:  0.02   loss:  0.63
#                      odds            win:  2.83   X: 58.00   loss:  1.59
#
#   5.5 <= y <   7.5:  d.pts:    79    win:    19   X:     0   loss:    60
#                      percentages     win:  0.24   X:  0.00   loss:  0.76
#                      odds            win:  4.16   X:   inf   loss:  1.32
#
#   7.5 <= y <  10.5:  d.pts:    38    win:     9   X:     0   loss:    29
#                      percentages     win:  0.24   X:  0.00   loss:  0.76
#                      odds            win:  4.22   X:   inf   loss:  1.31
#
#  10.5 <= y <  20.0:  d.pts:     8    win:     1   X:     0   loss:     7
#                      percentages     win:  0.12   X:  0.00   loss:  0.88
#                      odds            win:  8.00   X:   inf   loss:  1.14
# /Users/possanner/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:150: RuntimeWarning: invalid value encountered in double_scalars
# /Users/possanner/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:151: RuntimeWarning: invalid value encountered in double_scalars
# /Users/possanner/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:151: RuntimeWarning: divide by zero encountered in double_scalars

# %%
data_all
# Out:
# array([[-20. ,   0. ,   0. ,   0. ,   0. ,   0. ,   0. ],
#        [-19.5,   0. ,   0. ,   0. ,   0. ,   0. ,   0. ],
#        [-19. ,   0. ,   0. ,   0. ,   0. ,   0. ,   0. ],
#        [-18.5,   0. ,   0. ,   0. ,   0. ,   0. ,   0. ],
#        [-18. ,   0. ,   0. ,   0. ,   0. ,   0. ,   0. ],
#        [-17.5,   0. ,   0. ,   0. ,   0. ,   0. ,   0. ],
#        [-17. ,   0. ,   0. ,   0. ,   0. ,   0. ,   0. ],
#        [-16.5,   0. ,   0. ,   0. ,   0. ,   0. ,   0. ],
#        [-16. ,   0. ,   0. ,   0. ,   0. ,   0. ,   0. ],
#        [-15.5,   0. ,   0. ,   0. ,   0. ,   0. ,   0. ],
#        [-15. ,   0. ,   0. ,   0. ,   0. ,   0. ,   0. ],
#        [-14.5,   0. ,   0. ,   0. ,   0. ,   0. ,   0. ],
#        [-14. ,   0. ,   0. ,   0. ,   0. ,   0. ,   0. ],
#        [-13.5,   0. ,   0. ,   0. ,   0. ,   0. ,   0. ],
#        [-13. ,   0. ,   0. ,   0. ,   0. ,   0. ,   0. ],
#        [-12.5,   0. ,   0. ,   0. ,   0. ,   0. ,   0. ],
#        [-12. ,   0. ,   0. ,   0. ,   0. ,   0. ,   0. ],
#        [-11.5,   0. ,   0. ,   0. ,   0. ,   0. ,   0. ],
#        [-11. ,   0. ,   0. ,   0. ,   0. ,   0. ,   0. ],
#        [-10.5,   0. ,   0. ,   0. ,   0. ,   0. ,   0. ],
#        [-10. ,   0. ,   0. ,   0. ,   0. ,   0. ,   0. ],
#        [ -9.5,   0. ,   0. ,   0. ,   0. ,   0. ,   0. ],
#        [ -9. ,   0. ,   0. ,   0. ,   0. ,   0. ,   0. ],
#        [ -8.5,   0. ,   0. ,   0. ,   0. ,   0. ,   0. ],
#        [ -8. ,   0. ,   0. ,   0. ,   0. ,   0. ,   0. ],
#        [ -7.5,   0. ,   0. ,   0. ,   0. ,   0. ,   0. ],
#        [ -7. ,   0. ,   0. ,   0. ,   0. ,   0. ,   0. ],
#        [ -6.5,   2. ,   2. ,   0. ,   0. ,   0. ,   0. ],
#        [ -6. ,   0. ,   0. ,   0. ,   0. ,   0. ,   0. ],
#        [ -5.5,   2. ,   1. ,   0. ,   1. ,   0. ,   0. ],
#        [ -5. ,   4. ,   2. ,   0. ,   2. ,   0. ,   0. ],
#        [ -4.5,   0. ,   0. ,   0. ,   0. ,   0. ,   0. ],
#        [ -4. ,   0. ,   0. ,   0. ,   0. ,   0. ,   0. ],
#        [ -3.5,   1. ,   1. ,   0. ,   0. ,   0. ,   0. ],
#        [ -3. ,   5. ,   4. ,   0. ,   1. ,   0. ,   0. ],
#        [ -2.5,   4. ,   3. ,   0. ,   1. ,   0. ,   0. ],
#        [ -2. ,   5. ,   2. ,   0. ,   3. ,   0. ,   0. ],
#        [ -1.5,   9. ,   7. ,   0. ,   2. ,   0. ,   0. ],
#        [ -1. ,   4. ,   3. ,   0. ,   1. ,   0. ,   0. ],
#        [ -0.5,  15. ,   6. ,   0. ,   9. ,   0. ,   0. ],
#        [  0. ,  21. ,  11. ,   0. ,  10. ,   0. ,   0. ],
#        [  0.5,  20. ,  11. ,   0. ,   9. ,   0. ,   0. ],
#        [  1. ,  19. ,   9. ,   0. ,  10. ,   0. ,   0. ],
#        [  1.5,  24. ,  18. ,   0. ,   6. ,   0. ,   0. ],
#        [  2. ,  29. ,  12. ,   0. ,  17. ,   0. ,   0. ],
#        [  2.5,  22. ,  13. ,   0. ,   9. ,   0. ,   0. ],
#        [  3. ,  22. ,  13. ,   0. ,   9. ,   0. ,   0. ],
#        [  3.5,  34. ,  15. ,   1. ,  18. ,   0. ,   0. ],
#        [  4. ,  23. ,   9. ,   0. ,  14. ,   0. ,   0. ],
#        [  4.5,  31. ,  11. ,   1. ,  19. ,   0. ,   0. ],
#        [  5. ,  28. ,   6. ,   0. ,  22. ,   0. ,   0. ],
#        [  5.5,  25. ,   4. ,   0. ,  21. ,   0. ,   0. ],
#        [  6. ,  19. ,   5. ,   0. ,  14. ,   0. ,   0. ],
#        [  6.5,  17. ,   3. ,   0. ,  14. ,   0. ,   0. ],
#        [  7. ,  18. ,   7. ,   0. ,  11. ,   0. ,   0. ],
#        [  7.5,  13. ,   5. ,   0. ,   8. ,   0. ,   0. ],
#        [  8. ,   5. ,   1. ,   0. ,   4. ,   0. ,   0. ],
#        [  8.5,   6. ,   1. ,   0. ,   5. ,   0. ,   0. ],
#        [  9. ,  10. ,   2. ,   0. ,   8. ,   0. ,   0. ],
#        [  9.5,   4. ,   0. ,   0. ,   4. ,   0. ,   0. ],
#        [ 10. ,   0. ,   0. ,   0. ,   0. ,   0. ,   0. ],
#        [ 10.5,   4. ,   0. ,   0. ,   4. ,   0. ,   0. ],
#        [ 11. ,   0. ,   0. ,   0. ,   0. ,   0. ,   0. ],
#        [ 11.5,   3. ,   1. ,   0. ,   2. ,   0. ,   0. ],
#        [ 12. ,   0. ,   0. ,   0. ,   0. ,   0. ,   0. ],
#        [ 12.5,   0. ,   0. ,   0. ,   0. ,   0. ,   0. ],
#        [ 13. ,   0. ,   0. ,   0. ,   0. ,   0. ,   0. ],
#        [ 13.5,   1. ,   0. ,   0. ,   1. ,   0. ,   0. ],
#        [ 14. ,   0. ,   0. ,   0. ,   0. ,   0. ,   0. ],
#        [ 14.5,   0. ,   0. ,   0. ,   0. ,   0. ,   0. ],
#        [ 15. ,   0. ,   0. ,   0. ,   0. ,   0. ,   0. ],
#        [ 15.5,   0. ,   0. ,   0. ,   0. ,   0. ,   0. ],
#        [ 16. ,   0. ,   0. ,   0. ,   0. ,   0. ,   0. ],
#        [ 16.5,   0. ,   0. ,   0. ,   0. ,   0. ,   0. ],
#        [ 17. ,   0. ,   0. ,   0. ,   0. ,   0. ,   0. ],
#        [ 17.5,   0. ,   0. ,   0. ,   0. ,   0. ,   0. ],
#        [ 18. ,   0. ,   0. ,   0. ,   0. ,   0. ,   0. ],
#        [ 18.5,   0. ,   0. ,   0. ,   0. ,   0. ,   0. ],
#        [ 19. ,   0. ,   0. ,   0. ,   0. ,   0. ,   0. ],
#        [ 19.5,   0. ,   0. ,   0. ,   0. ,   0. ,   0. ],
#        [ 20. ,   0. ,   0. ,   0. ,   0. ,   0. ,   0. ]])

# %%
score_away
# Out:
# 24
