# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
lines = np.arange(-40, 41)
siz = len(lines)
data_all = np.zeros((siz, 7))
data_all[:, 0] = lines

bins1 = [0.0]
edges1 = [-40, 40]

bins2 = [-20, 20]
edges2 = [-40, 0, 40]

bins6 = [-30, -18, -6, 6, 18, 30]
edges6 = [-40, -24, -12, 0, 12, 24, 40]

bins7 = [-35, -24, -12, 0, 12, 24, 35]
edges7 = [-40, -30, -18, -6, 6, 18, 30, 40]

bins12 = [-33, -27, -21, -15, -9, -3, 3, 9, 15, 21, 27, 33]
edges12 = [-40, -30, -24, -18, -12, -6, 0, 6, 12, 18, 24, 30, 40]

leagues = ['Premier2018', 'Championship2018', 'SerieA2018']
start_week = [20, 24, 19]
end_week = [20, 26, 19]

# %%
2 >= 2
# Out:
# True

# %%
k = 0
print('In what follows y denotes the spread:')
for l in leagues:
    print()
    print('### league:', l)
    data = np.zeros((siz, 7))
    data[:, 0] = lines
    
    for wk in range(start_week[k], end_week[k] + 1):
        print('week:', wk)
        f = open(l + '/Week' + str(wk) + '/Results_w' + str(wk) + '.txt')
        Results = list(f)
        g = open(l + '/Week' + str(wk) + '/Lines_w' + str(wk) + '.txt')
        Lines = list(g)

        for i in range(len(Results)):
            j1 = Results[i].index('\t')
            j2 = Results[i].index('\t', j1 + 1)
            j3 = Results[i].index('\t', j2 + 1)
            home = int(Results[i][j2 + 1])
            away = int(Results[i][j3 - 2])
            line1 = float(Lines[i][0:4])
            line2 = int(line1*10)
            #print(home, away, line1, line2)
            ind = lines == line2
            #print(ind)
            data[ind, 1] += 1.
            data_all[ind, 1] += 1.
            if home - away > 0:
                data[ind, 2] += 1.
                data_all[ind, 2] += 1.
                if home - away >= 2:
                    data[ind, 5] += 1.
                    data_all[ind, 5] += 1.  
                if home - away >= 3:
                    data[ind, 6] += 1.
                    data_all[ind, 6] += 1.
            elif home - away < 0:
                data[ind, 4] += 1.
                data_all[ind, 4] += 1.
            else:
                data[ind, 3] += 1.
                data_all[ind, 3] += 1.
        
        #print('data:')
        #print(data)
        #print()
        #print('data_all:')
        #print(data_all)
        #print()

        f.close()
        g.close()
    
    if False:
        # one bin:
        ind = np.arange(2)
        ind[0] = np.where(lines == edges1[0])[0][0]
        ind[1] = np.where(lines == edges1[1])[0][0]
        games = np.sum(data[ind[0]:ind[1], 1])
        wins = np.sum(data[ind[0]:ind[1], 2])
        ties = np.sum(data[ind[0]:ind[1], 3])
        losses = np.sum(data[ind[0]:ind[1], 4])
        margin2 = np.sum(data[ind[0]:ind[1], 5])
        margin3 = np.sum(data[ind[0]:ind[1], 6])
        print()
        print('1 bin:')
        print()
        print('{:3d}'.format(-40) + '<= y <' + '{:3d}'.format(40) + ':  d.pts: {0:5.0f}    win: {1:5.0f}   X: {2:5.0f}   loss: {3:5.0f}'.format(games, wins, ties, losses))
        print('               percentages     win: {1:5.2f}   X: {2:5.2f}   loss: {3:5.2f}   1X: {4:5.2f}   X2: {5:5.2f}'.format(games, wins/games, ties/games, losses/games, (wins + ties)/games, (losses + ties)/games))
        print('               odds            win: {1:5.2f}   X: {2:5.2f}   loss: {3:5.2f}   1X: {4:5.2f}   X2: {5:5.2f}'.format(games, games/wins, games/ties, games/losses, games/(wins + ties), games/(losses + ties)))
        print('       >=2 goals difference in win: {0:5.0f}  percentage: {1:5.2f}  odds: {2:5.2f}'.format(margin2, margin2/games, games/margin2))
        print('       >=3 goals difference in win: {0:5.0f}  percentage: {1:5.2f}  odds: {2:5.2f}'.format(margin3, margin3/games, games/margin3))

        # seven bins:
        ind = np.arange(8)
        ind[0] = np.where(lines == edges7[0])[0][0]
        ind[1] = np.where(lines == edges7[1])[0][0]
        ind[2] = np.where(lines == edges7[2])[0][0]
        ind[3] = np.where(lines == edges7[3])[0][0]
        ind[4] = np.where(lines == edges7[4])[0][0]
        ind[5] = np.where(lines == edges7[5])[0][0]
        ind[6] = np.where(lines == edges7[6])[0][0]
        ind[7] = np.where(lines == edges7[7])[0][0]
        #print(ind)
        print()
        print('7 bins:')
        for i in range(len(ind) - 1):
            games = np.sum(data[ind[i]:ind[i + 1], 1])
            wins = np.sum(data[ind[i]:ind[i + 1], 2])
            ties = np.sum(data[ind[i]:ind[i + 1], 3])
            losses = np.sum(data[ind[i]:ind[i + 1], 4])
            margin2 = np.sum(data[ind[i]:ind[i + 1], 5])
            margin3 = np.sum(data[ind[i]:ind[i + 1], 6])
            print()
            print('{:3d}'.format(lines[ind[i]]) + '<= y <' + '{:3d}'.format(lines[ind[i + 1]]) + ':  d.pts: {0:5.0f}    win: {1:5.0f}   X: {2:5.0f}   loss: {3:5.0f}'.format(games, wins, ties, losses))
            print('               percentages     win: {1:5.2f}   X: {2:5.2f}   loss: {3:5.2f}   1X: {4:5.2f}   X2: {5:5.2f}'.format(games, wins/games, ties/games, losses/games, (wins + ties)/games, (losses + ties)/games))
            print('               odds            win: {1:5.2f}   X: {2:5.2f}   loss: {3:5.2f}   1X: {4:5.2f}   X2: {5:5.2f}'.format(games, games/wins, games/ties, games/losses, games/(wins + ties), games/(losses + ties)))
            print('       >=2 goals difference in win: {0:5.0f}  percentage: {1:5.2f}  odds: {2:5.2f}'.format(margin2, margin2/games, games/margin2))
            print('       >=3 goals difference in win: {0:5.0f}  percentage: {1:5.2f}  odds: {2:5.2f}'.format(margin3, margin3/games, games/margin3))
    
    k += 1
    
print()
print('### TOTAL:')

# one bin:
ind = np.arange(2)
ind[0] = np.where(lines == edges1[0])[0][0]
ind[1] = np.where(lines == edges1[1])[0][0]
games = np.sum(data_all[ind[0]:ind[1], 1])
wins = np.sum(data_all[ind[0]:ind[1], 2])
ties = np.sum(data_all[ind[0]:ind[1], 3])
losses = np.sum(data_all[ind[0]:ind[1], 4])
margin2 = np.sum(data_all[ind[0]:ind[1], 5])
margin3 = np.sum(data_all[ind[0]:ind[1], 6])
print()
print('1 bin:')
print()
print('{:3d}'.format(-40) + '<= y <' + '{:3d}'.format(40) + ':  d.pts: {0:5.0f}    win: {1:5.0f}   X: {2:5.0f}   loss: {3:5.0f}'.format(games, wins, ties, losses))
print('               percentages     win: {1:5.2f}   X: {2:5.2f}   loss: {3:5.2f}   1X: {4:5.2f}   X2: {5:5.2f}'.format(games, wins/games, ties/games, losses/games, (wins + ties)/games, (losses + ties)/games))
print('               odds            win: {1:5.2f}   X: {2:5.2f}   loss: {3:5.2f}   1X: {4:5.2f}   X2: {5:5.2f}'.format(games, games/wins, games/ties, games/losses, games/(wins + ties), games/(losses + ties)))
print('       >=2 goals difference in win: {0:5.0f}  percentage: {1:5.2f}  odds: {2:5.2f}'.format(margin2, margin2/games, games/margin2))
print('       >=3 goals difference in win: {0:5.0f}  percentage: {1:5.2f}  odds: {2:5.2f}'.format(margin3, margin3/games, games/margin3))
    
# seven bins:
ind = np.arange(8)
ind[0] = np.where(lines == edges7[0])[0][0]
ind[1] = np.where(lines == edges7[1])[0][0]
ind[2] = np.where(lines == edges7[2])[0][0]
ind[3] = np.where(lines == edges7[3])[0][0]
ind[4] = np.where(lines == edges7[4])[0][0]
ind[5] = np.where(lines == edges7[5])[0][0]
ind[6] = np.where(lines == edges7[6])[0][0]
ind[7] = np.where(lines == edges7[7])[0][0]
#print(ind)
print()
print('7 bins:')
for i in range(len(ind) - 1):
    games = np.sum(data_all[ind[i]:ind[i + 1], 1])
    wins = np.sum(data_all[ind[i]:ind[i + 1], 2])
    ties = np.sum(data_all[ind[i]:ind[i + 1], 3])
    losses = np.sum(data_all[ind[i]:ind[i + 1], 4])
    margin2 = np.sum(data_all[ind[i]:ind[i + 1], 5])
    margin3 = np.sum(data_all[ind[i]:ind[i + 1], 6])
    print()
    print('{:3d}'.format(lines[ind[i]]) + '<= y <' + '{:3d}'.format(lines[ind[i + 1]]) + ':  d.pts: {0:5.0f}    win: {1:5.0f}   X: {2:5.0f}   loss: {3:5.0f}'.format(games, wins, ties, losses))
    print('               percentages     win: {1:5.2f}   X: {2:5.2f}   loss: {3:5.2f}   1X: {4:5.2f}   X2: {5:5.2f}'.format(games, wins/games, ties/games, losses/games, (wins + ties)/games, (losses + ties)/games))
    print('               odds            win: {1:5.2f}   X: {2:5.2f}   loss: {3:5.2f}   1X: {4:5.2f}   X2: {5:5.2f}'.format(games, games/wins, games/ties, games/losses, games/(wins + ties), games/(losses + ties)))
    print('       >=2 goals difference in win: {0:5.0f}  percentage: {1:5.2f}  odds: {2:5.2f}'.format(margin2, margin2/games, games/margin2))
    print('       >=3 goals difference in win: {0:5.0f}  percentage: {1:5.2f}  odds: {2:5.2f}'.format(margin3, margin3/games, games/margin3))
# Out:
# In what follows y denotes the spread:
#
# ### league: Premier2018
# week: 20
#
# ### league: Championship2018
# week: 24
# week: 25
# week: 26
#
# ### league: SerieA2018
# week: 19
#
# ### TOTAL:
#
# 1 bin:
#
# -40<= y < 40:  d.pts:    56    win:    25   X:    15   loss:    16
#                percentages     win:  0.45   X:  0.27   loss:  0.29   1X:  0.71   X2:  0.55
#                odds            win:  2.24   X:  3.73   loss:  3.50   1X:  1.40   X2:  1.81
#        >=2 goals difference in win:    12  percentage:  0.21  odds:  4.67
#        >=3 goals difference in win:     5  percentage:  0.09  odds: 11.20
#
# 7 bins:
#
# -40<= y <-30:  d.pts:     0    win:     0   X:     0   loss:     0
#                percentages     win:   nan   X:   nan   loss:   nan   1X:   nan   X2:   nan
#                odds            win:   nan   X:   nan   loss:   nan   1X:   nan   X2:   nan
#        >=2 goals difference in win:     0  percentage:   nan  odds:   nan
# ...
