# %%
import numpy as np
import matplotlib.pyplot as plt

def redpr(str):
    print('\x1b[31m' + str + '\x1b[0m')

# %%
lines = np.arange(-40, 41)
siz = len(lines)
data_all = np.zeros((siz, 7))
data_all[:, 0] = lines

conv_kernel = 6

leagues = ['Premier2018', 'Championship2018', 'SerieA2018']
start_week = [20, 24, 19]
end_week = [21, 26, 19]

# %%
len(lines)
# Out:
# 81

# %%
k = 0
print('In what follows y denotes the spread:')
for l in leagues:
    print()
    print('### league:', l)
    data = np.zeros((siz, 7))
    data[:, 0] = lines
    
    for wk in range(start_week[k], end_week[k] + 1):
        print('week:', wk)
        f = open(l + '/Week' + str(wk) + '/Results_w' + str(wk) + '.txt')
        Results = list(f)
        g = open(l + '/Week' + str(wk) + '/Lines_w' + str(wk) + '.txt')
        Lines = list(g)

        for i in range(len(Results)):
            j1 = Results[i].index('\t')
            j2 = Results[i].index('\t', j1 + 1)
            j3 = Results[i].index('\t', j2 + 1)
            home = int(Results[i][j2 + 1])
            away = int(Results[i][j3 - 2])
            line1 = float(Lines[i][0:4])
            line2 = int(line1*10)
            #print(home, away, line1, line2)
            ind = lines == line2
            #print(ind)
            data[ind, 1] += 1.
            data_all[ind, 1] += 1.
            if home - away > 0:
                data[ind, 2] += 1.
                data_all[ind, 2] += 1.
                if home - away >= 2:
                    data[ind, 5] += 1.
                    data_all[ind, 5] += 1.  
                if home - away >= 3:
                    data[ind, 6] += 1.
                    data_all[ind, 6] += 1.
            elif home - away < 0:
                data[ind, 4] += 1.
                data_all[ind, 4] += 1.
            else:
                data[ind, 3] += 1.
                data_all[ind, 3] += 1.
        
        #print('data:')
        #print(data)
        #print()
        #print('data_all:')
        #print(data_all)
        #print()

        f.close()
        g.close()
    
    k += 1
    
print()
print('### TOTAL:')

# one bin:
games = np.sum(data_all[:, 1])
wins = np.sum(data_all[:, 2])
ties = np.sum(data_all[:, 3])
losses = np.sum(data_all[:, 4])
margin2 = np.sum(data_all[:, 5])
margin3 = np.sum(data_all[:, 6])
print()
print('1 bin:')
print()
redpr('{:3d}'.format(-40) + '<= y <' + '{:3d}'.format(40) + ':  d.pts: {0:5.0f}    win: {1:5.0f}   X: {2:5.0f}   loss: {3:5.0f}'.format(games, wins, ties, losses))
print('               percentages     win: {1:5.2f}   X: {2:5.2f}   loss: {3:5.2f}   1X: {4:5.2f}   X2: {5:5.2f}'.format(games, wins/games, ties/games, losses/games, (wins + ties)/games, (losses + ties)/games))
redpr('               odds            win: {1:5.2f}   X: {2:5.2f}   loss: {3:5.2f}   1X: {4:5.2f}   X2: {5:5.2f}'.format(games, games/wins, games/ties, games/losses, games/(wins + ties), games/(losses + ties)))
print('       >=2 goals difference in win: {0:5.0f}  percentage: {1:5.2f}  odds: {2:5.2f}'.format(margin2, margin2/games, games/margin2))
print('       >=3 goals difference in win: {0:5.0f}  percentage: {1:5.2f}  odds: {2:5.2f}'.format(margin3, margin3/games, games/margin3))
    
print()
print('all bins:')
for i in range(conv_kernel, len(lines) - conv_kernel):
    #print('i', i, i - conv_kernel, i + conv_kernel)
    games = np.sum(data_all[i - conv_kernel:i + conv_kernel, 1])
    wins = np.sum(data_all[i - conv_kernel:i + conv_kernel, 2])
    ties = np.sum(data_all[i - conv_kernel:i + conv_kernel, 3])
    losses = np.sum(data_all[i - conv_kernel:i + conv_kernel, 4])
    margin2 = np.sum(data_all[i - conv_kernel:i + conv_kernel, 5])
    margin3 = np.sum(data_all[i - conv_kernel:i + conv_kernel, 6])
    print()
    redpr('{:3d}'.format(lines[i]) + ':  d.pts: {0:5.0f}    win: {1:5.0f}   X: {2:5.0f}   loss: {3:5.0f}'.format(games, wins, ties, losses))
    print('               percentages     win: {1:5.2f}   X: {2:5.2f}   loss: {3:5.2f}   1X: {4:5.2f}   X2: {5:5.2f}'.format(games, wins/games, ties/games, losses/games, (wins + ties)/games, (losses + ties)/games))
    redpr('               odds            win: {1:5.2f}   X: {2:5.2f}   loss: {3:5.2f}   1X: {4:5.2f}   X2: {5:5.2f}'.format(games, games/wins, games/ties, games/losses, games/(wins + ties), games/(losses + ties)))
    print('       >=2 goals difference in win: {0:5.0f}  percentage: {1:5.2f}  odds: {2:5.2f}'.format(margin2, margin2/games, games/margin2))
    print('       >=3 goals difference in win: {0:5.0f}  percentage: {1:5.2f}  odds: {2:5.2f}'.format(margin3, margin3/games, games/margin3))
# Out:
# In what follows y denotes the spread:
#
# ### league: Premier2018
# week: 20
# week: 21
#
# ### league: Championship2018
# week: 24
# week: 25
# week: 26
#
# ### league: SerieA2018
# week: 19
#
# ### TOTAL:
#
# 1 bin:
#
# -40<= y < 40:  d.pts:    66    win:    27   X:    18   loss:    21
#                percentages     win:  0.41   X:  0.27   loss:  0.32   1X:  0.68   X2:  0.59
#                odds            win:  2.44   X:  3.67   loss:  3.14   1X:  1.47   X2:  1.69
#        >=2 goals difference in win:    13  percentage:  0.20  odds:  5.08
#        >=3 goals difference in win:     6  percentage:  0.09  odds: 11.00
#
# all bins:
#
# -34:  d.pts:     0    win:     0   X:     0   loss:     0
#                percentages     win:   nan   X:   nan   loss:   nan   1X:   nan   X2:   nan
#                odds            win:   nan   X:   nan   loss:   nan   1X:   nan   X2:   nan
#        >=2 goals difference in win:     0  percentage:   nan  odds:   nan
#        >=3 goals difference in win:     0  percentage:   nan  odds:   nan
#
# -33:  d.pts:     0    win:     0   X:     0   loss:     0
#                percentages     win:   nan   X:   nan   loss:   nan   1X:   nan   X2:   nan
#                odds            win:   nan   X:   nan   loss:   nan   1X:   nan   X2:   nan
#        >=2 goals difference in win:     0  percentage:   nan  odds:   nan
#        >=3 goals difference in win:     0  percentage:   nan  odds:   nan
#
# -32:  d.pts:     0    win:     0   X:     0   loss:     0
#                percentages     win:   nan   X:   nan   loss:   nan   1X:   nan   X2:   nan
#                odds            win:   nan   X:   nan   loss:   nan   1X:   nan   X2:   nan
#        >=2 goals difference in win:     0  percentage:   nan  odds:   nan
#        >=3 goals difference in win:     0  percentage:   nan  odds:   nan
#
# -31:  d.pts:     0    win:     0   X:     0   loss:     0
#                percentages     win:   nan   X:   nan   loss:   nan   1X:   nan   X2:   nan
#                odds            win:   nan   X:   nan   loss:   nan   1X:   nan   X2:   nan
#        >=2 goals difference in win:     0  percentage:   nan  odds:   nan
#        >=3 goals difference in win:     0  percentage:   nan  odds:   nan
#
# -30:  d.pts:     1    win:     1   X:     0   loss:     0
#                percentages     win:  1.00   X:  0.00   loss:  0.00   1X:  1.00   X2:  0.00
#                odds            win:  1.00   X:   inf   loss:   inf   1X:  1.00   X2:   inf
#        >=2 goals difference in win:     0  percentage:  0.00  odds:   inf
#        >=3 goals difference in win:     0  percentage:  0.00  odds:   inf
#
# -29:  d.pts:     1    win:     1   X:     0   loss:     0
#                percentages     win:  1.00   X:  0.00   loss:  0.00   1X:  1.00   X2:  0.00
#                odds            win:  1.00   X:   inf   loss:   inf   1X:  1.00   X2:   inf
#        >=2 goals difference in win:     0  percentage:  0.00  odds:   inf
#        >=3 goals difference in win:     0  percentage:  0.00  odds:   inf
#
# -28:  d.pts:     1    win:     1   X:     0   loss:     0
#                percentages     win:  1.00   X:  0.00   loss:  0.00   1X:  1.00   X2:  0.00
#                odds            win:  1.00   X:   inf   loss:   inf   1X:  1.00   X2:   inf
#        >=2 goals difference in win:     0  percentage:  0.00  odds:   inf
#        >=3 goals difference in win:     0  percentage:  0.00  odds:   inf
#
# -27:  d.pts:     1    win:     1   X:     0   loss:     0
#                percentages     win:  1.00   X:  0.00   loss:  0.00   1X:  1.00   X2:  0.00
#                odds            win:  1.00   X:   inf   loss:   inf   1X:  1.00   X2:   inf
#        >=2 goals difference in win:     0  percentage:  0.00  odds:   inf
#        >=3 goals difference in win:     0  percentage:  0.00  odds:   inf
#
# -26:  d.pts:     1    win:     1   X:     0   loss:     0
#                percentages     win:  1.00   X:  0.00   loss:  0.00   1X:  1.00   X2:  0.00
#                odds            win:  1.00   X:   inf   loss:   inf   1X:  1.00   X2:   inf
#        >=2 goals difference in win:     0  percentage:  0.00  odds:   inf
#        >=3 goals difference in win:     0  percentage:  0.00  odds:   inf
#
# -25:  d.pts:     2    win:     2   X:     0   loss:     0
#                percentages     win:  1.00   X:  0.00   loss:  0.00   1X:  1.00   X2:  0.00
#                odds            win:  1.00   X:   inf   loss:   inf   1X:  1.00   X2:   inf
#        >=2 goals difference in win:     0  percentage:  0.00  odds:   inf
#        >=3 goals difference in win:     0  percentage:  0.00  odds:   inf
#
# -24:  d.pts:     2    win:     2   X:     0   loss:     0
#                percentages     win:  1.00   X:  0.00   loss:  0.00   1X:  1.00   X2:  0.00
#                odds            win:  1.00   X:   inf   loss:   inf   1X:  1.00   X2:   inf
#        >=2 goals difference in win:     0  percentage:  0.00  odds:   inf
#        >=3 goals difference in win:     0  percentage:  0.00  odds:   inf
#
# -23:  d.pts:     4    win:     4   X:     0   loss:     0
#                percentages     win:  1.00   X:  0.00   loss:  0.00   1X:  1.00   X2:  0.00
#                odds            win:  1.00   X:   inf   loss:   inf   1X:  1.00   X2:   inf
#        >=2 goals difference in win:     2  percentage:  0.50  odds:  2.00
#        >=3 goals difference in win:     1  percentage:  0.25  odds:  4.00
#
# -22:  d.pts:     5    win:     4   X:     1   loss:     0
#                percentages     win:  0.80   X:  0.20   loss:  0.00   1X:  1.00   X2:  0.20
#                odds            win:  1.25   X:  5.00   loss:   inf   1X:  1.00   X2:  5.00
#        >=2 goals difference in win:     2  percentage:  0.40  odds:  2.50
#        >=3 goals difference in win:     1  percentage:  0.20  odds:  5.00
#
# -21:  d.pts:     7    win:     4   X:     2   loss:     1
#                percentages     win:  0.57   X:  0.29   loss:  0.14   1X:  0.86   X2:  0.43
#                odds            win:  1.75   X:  3.50   loss:  7.00   1X:  1.17   X2:  2.33
#        >=2 goals difference in win:     2  percentage:  0.29  odds:  3.50
#        >=3 goals difference in win:     1  percentage:  0.14  odds:  7.00
#
# -20:  d.pts:     9    win:     6   X:     2   loss:     1
#                percentages     win:  0.67   X:  0.22   loss:  0.11   1X:  0.89   X2:  0.33
#                odds            win:  1.50   X:  4.50   loss:  9.00   1X:  1.12   X2:  3.00
#        >=2 goals difference in win:     4  percentage:  0.44  odds:  2.25
#        >=3 goals difference in win:     2  percentage:  0.22  odds:  4.50
#
# -19:  d.pts:     9    win:     6   X:     2   loss:     1
#                percentages     win:  0.67   X:  0.22   loss:  0.11   1X:  0.89   X2:  0.33
#                odds            win:  1.50   X:  4.50   loss:  9.00   1X:  1.12   X2:  3.00
#        >=2 goals difference in win:     4  percentage:  0.44  odds:  2.25
#        >=3 goals difference in win:     2  percentage:  0.22  odds:  4.50
#
# -18:  d.pts:    11    win:     7   X:     2   loss:     2
#                percentages     win:  0.64   X:  0.18   loss:  0.18   1X:  0.82   X2:  0.36
#                odds            win:  1.57   X:  5.50   loss:  5.50   1X:  1.22   X2:  2.75
#        >=2 goals difference in win:     6  percentage:  0.55  odds:  1.83
#        >=3 goals difference in win:     4  percentage:  0.36  odds:  2.75
#
# -17:  d.pts:    16    win:    11   X:     2   loss:     3
#                percentages     win:  0.69   X:  0.12   loss:  0.19   1X:  0.81   X2:  0.31
#                odds            win:  1.45   X:  8.00   loss:  5.33   1X:  1.23   X2:  3.20
#        >=2 goals difference in win:     7  percentage:  0.44  odds:  2.29
#        >=3 goals difference in win:     5  percentage:  0.31  odds:  3.20
#
# -16:  d.pts:    18    win:    11   X:     4   loss:     3
#                percentages     win:  0.61   X:  0.22   loss:  0.17   1X:  0.83   X2:  0.39
#                odds            win:  1.64   X:  4.50   loss:  6.00   1X:  1.20   X2:  2.57
#        >=2 goals difference in win:     7  percentage:  0.39  odds:  2.57
#        >=3 goals difference in win:     5  percentage:  0.28  odds:  3.60
#
# -15:  d.pts:    20    win:    12   X:     5   loss:     3
#                percentages     win:  0.60   X:  0.25   loss:  0.15   1X:  0.85   X2:  0.40
#                odds            win:  1.67   X:  4.00   loss:  6.67   1X:  1.18   X2:  2.50
#        >=2 goals difference in win:     8  percentage:  0.40  odds:  2.50
#        >=3 goals difference in win:     6  percentage:  0.30  odds:  3.33
#
# -14:  d.pts:    22    win:    12   X:     7   loss:     3
#                percentages     win:  0.55   X:  0.32   loss:  0.14   1X:  0.86   X2:  0.45
#                odds            win:  1.83   X:  3.14   loss:  7.33   1X:  1.16   X2:  2.20
#        >=2 goals difference in win:     8  percentage:  0.36  odds:  2.75
#        >=3 goals difference in win:     6  percentage:  0.27  odds:  3.67
#
# -13:  d.pts:    25    win:    12   X:     7   loss:     6
#                percentages     win:  0.48   X:  0.28   loss:  0.24   1X:  0.76   X2:  0.52
#                odds            win:  2.08   X:  3.57   loss:  4.17   1X:  1.32   X2:  1.92
#        >=2 goals difference in win:     8  percentage:  0.32  odds:  3.12
#        >=3 goals difference in win:     6  percentage:  0.24  odds:  4.17
#
# -12:  d.pts:    27    win:    12   X:     9   loss:     6
#                percentages     win:  0.44   X:  0.33   loss:  0.22   1X:  0.78   X2:  0.56
#                odds            win:  2.25   X:  3.00   loss:  4.50   1X:  1.29   X2:  1.80
#        >=2 goals difference in win:     8  percentage:  0.30  odds:  3.38
#        >=3 goals difference in win:     6  percentage:  0.22  odds:  4.50
#
# -11:  d.pts:    28    win:    11   X:    10   loss:     7
#                percentages     win:  0.39   X:  0.36   loss:  0.25   1X:  0.75   X2:  0.61
#                odds            win:  2.55   X:  2.80   loss:  4.00   1X:  1.33   X2:  1.65
#        >=2 goals difference in win:     6  percentage:  0.21  odds:  4.67
#        >=3 goals difference in win:     5  percentage:  0.18  odds:  5.60
#
# -10:  d.pts:    27    win:    11   X:     9   loss:     7
#                percentages     win:  0.41   X:  0.33   loss:  0.26   1X:  0.74   X2:  0.59
#                odds            win:  2.45   X:  3.00   loss:  3.86   1X:  1.35   X2:  1.69
#        >=2 goals difference in win:     6  percentage:  0.22  odds:  4.50
#        >=3 goals difference in win:     5  percentage:  0.19  odds:  5.40
#
#  -9:  d.pts:    28    win:    11   X:     9   loss:     8
#                percentages     win:  0.39   X:  0.32   loss:  0.29   1X:  0.71   X2:  0.61
#                odds            win:  2.55   X:  3.11   loss:  3.50   1X:  1.40   X2:  1.65
#        >=2 goals difference in win:     6  percentage:  0.21  odds:  4.67
#        >=3 goals difference in win:     5  percentage:  0.18  odds:  5.60
#
#  -8:  d.pts:    28    win:    10   X:     9   loss:     9
#                percentages     win:  0.36   X:  0.32   loss:  0.32   1X:  0.68   X2:  0.64
#                odds            win:  2.80   X:  3.11   loss:  3.11   1X:  1.47   X2:  1.56
#        >=2 goals difference in win:     4  percentage:  0.14  odds:  7.00
#        >=3 goals difference in win:     4  percentage:  0.14  odds:  7.00
#
#  -7:  d.pts:    31    win:    12   X:    10   loss:     9
#                percentages     win:  0.39   X:  0.32   loss:  0.29   1X:  0.71   X2:  0.61
#                odds            win:  2.58   X:  3.10   loss:  3.44   1X:  1.41   X2:  1.63
#        >=2 goals difference in win:     6  percentage:  0.19  odds:  5.17
#        >=3 goals difference in win:     4  percentage:  0.13  odds:  7.75
#
#  -6:  d.pts:    30    win:    11   X:    10   loss:     9
#                percentages     win:  0.37   X:  0.33   loss:  0.30   1X:  0.70   X2:  0.63
#                odds            win:  2.73   X:  3.00   loss:  3.33   1X:  1.43   X2:  1.58
#        >=2 goals difference in win:     4  percentage:  0.13  odds:  7.50
#        >=3 goals difference in win:     2  percentage:  0.07  odds: 15.00
#
#  -5:  d.pts:    27    win:     8   X:    11   loss:     8
#                percentages     win:  0.30   X:  0.41   loss:  0.30   1X:  0.70   X2:  0.70
#                odds            win:  3.38   X:  2.45   loss:  3.38   1X:  1.42   X2:  1.42
#        >=2 goals difference in win:     3  percentage:  0.11  odds:  9.00
#        >=3 goals difference in win:     1  percentage:  0.04  odds: 27.00
#
#  -4:  d.pts:    26    win:     9   X:     9   loss:     8
#                percentages     win:  0.35   X:  0.35   loss:  0.31   1X:  0.69   X2:  0.65
#                odds            win:  2.89   X:  2.89   loss:  3.25   1X:  1.44   X2:  1.53
#        >=2 goals difference in win:     4  percentage:  0.15  odds:  6.50
#        >=3 goals difference in win:     1  percentage:  0.04  odds: 26.00
#
#  -3:  d.pts:    27    win:     9   X:    10   loss:     8
#                percentages     win:  0.33   X:  0.37   loss:  0.30   1X:  0.70   X2:  0.67
#                odds            win:  3.00   X:  2.70   loss:  3.38   1X:  1.42   X2:  1.50
#        >=2 goals difference in win:     3  percentage:  0.11  odds:  9.00
#        >=3 goals difference in win:     0  percentage:  0.00  odds:   inf
#
#  -2:  d.pts:    27    win:    10   X:     9   loss:     8
#                percentages     win:  0.37   X:  0.33   loss:  0.30   1X:  0.70   X2:  0.63
#                odds            win:  2.70   X:  3.00   loss:  3.38   1X:  1.42   X2:  1.59
#        >=2 goals difference in win:     3  percentage:  0.11  odds:  9.00
#        >=3 goals difference in win:     0  percentage:  0.00  odds:   inf
#
#  -1:  d.pts:    25    win:     9   X:     9   loss:     7
#                percentages     win:  0.36   X:  0.36   loss:  0.28   1X:  0.72   X2:  0.64
#                odds            win:  2.78   X:  2.78   loss:  3.57   1X:  1.39   X2:  1.56
#        >=2 goals difference in win:     3  percentage:  0.12  odds:  8.33
#        >=3 goals difference in win:     0  percentage:  0.00  odds:   inf
#
#   0:  d.pts:    25    win:    10   X:     7   loss:     8
#                percentages     win:  0.40   X:  0.28   loss:  0.32   1X:  0.68   X2:  0.60
#                odds            win:  2.50   X:  3.57   loss:  3.12   1X:  1.47   X2:  1.67
#        >=2 goals difference in win:     3  percentage:  0.12  odds:  8.33
#        >=3 goals difference in win:     0  percentage:  0.00  odds:   inf
#
#   1:  d.pts:    24    win:     9   X:     8   loss:     7
#                percentages     win:  0.38   X:  0.33   loss:  0.29   1X:  0.71   X2:  0.62
#                odds            win:  2.67   X:  3.00   loss:  3.43   1X:  1.41   X2:  1.60
#        >=2 goals difference in win:     3  percentage:  0.12  odds:  8.00
#        >=3 goals difference in win:     0  percentage:  0.00  odds:   inf
#
#   2:  d.pts:    26    win:    10   X:     8   loss:     8
#                percentages     win:  0.38   X:  0.31   loss:  0.31   1X:  0.69   X2:  0.62
#                odds            win:  2.60   X:  3.25   loss:  3.25   1X:  1.44   X2:  1.62
#        >=2 goals difference in win:     4  percentage:  0.15  odds:  6.50
#        >=3 goals difference in win:     0  percentage:  0.00  odds:   inf
#
#   3:  d.pts:    23    win:    10   X:     7   loss:     6
#                percentages     win:  0.43   X:  0.30   loss:  0.26   1X:  0.74   X2:  0.57
#                odds            win:  2.30   X:  3.29   loss:  3.83   1X:  1.35   X2:  1.77
#        >=2 goals difference in win:     4  percentage:  0.17  odds:  5.75
#        >=3 goals difference in win:     0  percentage:  0.00  odds:   inf
#
#   4:  d.pts:    23    win:     9   X:     7   loss:     7
#                percentages     win:  0.39   X:  0.30   loss:  0.30   1X:  0.70   X2:  0.61
#                odds            win:  2.56   X:  3.29   loss:  3.29   1X:  1.44   X2:  1.64
#        >=2 goals difference in win:     4  percentage:  0.17  odds:  5.75
#        >=3 goals difference in win:     0  percentage:  0.00  odds:   inf
#
#   5:  d.pts:    21    win:     7   X:     6   loss:     8
#                percentages     win:  0.33   X:  0.29   loss:  0.38   1X:  0.62   X2:  0.67
#                odds            win:  3.00   X:  3.50   loss:  2.62   1X:  1.62   X2:  1.50
#        >=2 goals difference in win:     2  percentage:  0.10  odds: 10.50
#        >=3 goals difference in win:     0  percentage:  0.00  odds:   inf
#
#   6:  d.pts:    20    win:     6   X:     6   loss:     8
#                percentages     win:  0.30   X:  0.30   loss:  0.40   1X:  0.60   X2:  0.70
#                odds            win:  3.33   X:  3.33   loss:  2.50   1X:  1.67   X2:  1.43
#        >=2 goals difference in win:     2  percentage:  0.10  odds: 10.00
#        >=3 goals difference in win:     0  percentage:  0.00  odds:   inf
#
#   7:  d.pts:    19    win:     6   X:     5   loss:     8
#                percentages     win:  0.32   X:  0.26   loss:  0.42   1X:  0.58   X2:  0.68
#                odds            win:  3.17   X:  3.80   loss:  2.38   1X:  1.73   X2:  1.46
#        >=2 goals difference in win:     2  percentage:  0.11  odds:  9.50
#        >=3 goals difference in win:     0  percentage:  0.00  odds:   inf
#
#   8:  d.pts:    18    win:     5   X:     5   loss:     8
#                percentages     win:  0.28   X:  0.28   loss:  0.44   1X:  0.56   X2:  0.72
#                odds            win:  3.60   X:  3.60   loss:  2.25   1X:  1.80   X2:  1.38
#        >=2 goals difference in win:     1  percentage:  0.06  odds: 18.00
#        >=3 goals difference in win:     0  percentage:  0.00  odds:   inf
#
#   9:  d.pts:    15    win:     4   X:     3   loss:     8
#                percentages     win:  0.27   X:  0.20   loss:  0.53   1X:  0.47   X2:  0.73
#                odds            win:  3.75   X:  5.00   loss:  1.88   1X:  2.14   X2:  1.36
#        >=2 goals difference in win:     1  percentage:  0.07  odds: 15.00
#        >=3 goals difference in win:     0  percentage:  0.00  odds:   inf
#
#  10:  d.pts:    13    win:     3   X:     2   loss:     8
#                percentages     win:  0.23   X:  0.15   loss:  0.62   1X:  0.38   X2:  0.77
#                odds            win:  4.33   X:  6.50   loss:  1.62   1X:  2.60   X2:  1.30
#        >=2 goals difference in win:     1  percentage:  0.08  odds: 13.00
#        >=3 goals difference in win:     0  percentage:  0.00  odds:   inf
#
#  11:  d.pts:    13    win:     4   X:     2   loss:     7
#                percentages     win:  0.31   X:  0.15   loss:  0.54   1X:  0.46   X2:  0.69
#                odds            win:  3.25   X:  6.50   loss:  1.86   1X:  2.17   X2:  1.44
#        >=2 goals difference in win:     2  percentage:  0.15  odds:  6.50
#        >=3 goals difference in win:     0  percentage:  0.00  odds:   inf
#
#  12:  d.pts:    11    win:     3   X:     2   loss:     6
#                percentages     win:  0.27   X:  0.18   loss:  0.55   1X:  0.45   X2:  0.73
#                odds            win:  3.67   X:  5.50   loss:  1.83   1X:  2.20   X2:  1.38
#        >=2 goals difference in win:     2  percentage:  0.18  odds:  5.50
#        >=3 goals difference in win:     0  percentage:  0.00  odds:   inf
#
#  13:  d.pts:     9    win:     3   X:     0   loss:     6
#                percentages     win:  0.33   X:  0.00   loss:  0.67   1X:  0.33   X2:  0.67
#                odds            win:  3.00   X:   inf   loss:  1.50   1X:  3.00   X2:  1.50
#        >=2 goals difference in win:     2  percentage:  0.22  odds:  4.50
#        >=3 goals difference in win:     0  percentage:  0.00  odds:   inf
#
#  14:  d.pts:     7    win:     2   X:     0   loss:     5
#                percentages     win:  0.29   X:  0.00   loss:  0.71   1X:  0.29   X2:  0.71
#                odds            win:  3.50   X:   inf   loss:  1.40   1X:  3.50   X2:  1.40
#        >=2 goals difference in win:     1  percentage:  0.14  odds:  7.00
#        >=3 goals difference in win:     0  percentage:  0.00  odds:   inf
#
#  15:  d.pts:     8    win:     2   X:     0   loss:     6
#                percentages     win:  0.25   X:  0.00   loss:  0.75   1X:  0.25   X2:  0.75
#                odds            win:  4.00   X:   inf   loss:  1.33   1X:  4.00   X2:  1.33
#        >=2 goals difference in win:     1  percentage:  0.12  odds:  8.00
#        >=3 goals difference in win:     0  percentage:  0.00  odds:   inf
#
#  16:  d.pts:     6    win:     2   X:     0   loss:     4
#                percentages     win:  0.33   X:  0.00   loss:  0.67   1X:  0.33   X2:  0.67
#                odds            win:  3.00   X:   inf   loss:  1.50   1X:  3.00   X2:  1.50
#        >=2 goals difference in win:     1  percentage:  0.17  odds:  6.00
#        >=3 goals difference in win:     0  percentage:  0.00  odds:   inf
#
#  17:  d.pts:     5    win:     2   X:     0   loss:     3
#                percentages     win:  0.40   X:  0.00   loss:  0.60   1X:  0.40   X2:  0.60
#                odds            win:  2.50   X:   inf   loss:  1.67   1X:  2.50   X2:  1.67
#        >=2 goals difference in win:     1  percentage:  0.20  odds:  5.00
#        >=3 goals difference in win:     0  percentage:  0.00  odds:   inf
#
#  18:  d.pts:     4    win:     2   X:     0   loss:     2
#                percentages     win:  0.50   X:  0.00   loss:  0.50   1X:  0.50   X2:  0.50
#                odds            win:  2.00   X:   inf   loss:  2.00   1X:  2.00   X2:  2.00
#        >=2 goals difference in win:     1  percentage:  0.25  odds:  4.00
#        >=3 goals difference in win:     0  percentage:  0.00  odds:   inf
#
#  19:  d.pts:     3    win:     1   X:     0   loss:     2
#                percentages     win:  0.33   X:  0.00   loss:  0.67   1X:  0.33   X2:  0.67
#                odds            win:  3.00   X:   inf   loss:  1.50   1X:  3.00   X2:  1.50
#        >=2 goals difference in win:     1  percentage:  0.33  odds:  3.00
#        >=3 goals difference in win:     0  percentage:  0.00  odds:   inf
#
#  20:  d.pts:     3    win:     1   X:     0   loss:     2
#                percentages     win:  0.33   X:  0.00   loss:  0.67   1X:  0.33   X2:  0.67
#                odds            win:  3.00   X:   inf   loss:  1.50   1X:  3.00   X2:  1.50
#        >=2 goals difference in win:     1  percentage:  0.33  odds:  3.00
#        >=3 goals difference in win:     0  percentage:  0.00  odds:   inf
#
#  21:  d.pts:     3    win:     1   X:     0   loss:     2
#                percentages     win:  0.33   X:  0.00   loss:  0.67   1X:  0.33   X2:  0.67
#                odds            win:  3.00   X:   inf   loss:  1.50   1X:  3.00   X2:  1.50
#        >=2 goals difference in win:     1  percentage:  0.33  odds:  3.00
#        >=3 goals difference in win:     0  percentage:  0.00  odds:   inf
#
#  22:  d.pts:     3    win:     1   X:     0   loss:     2
#                percentages     win:  0.33   X:  0.00   loss:  0.67   1X:  0.33   X2:  0.67
#                odds            win:  3.00   X:   inf   loss:  1.50   1X:  3.00   X2:  1.50
#        >=2 goals difference in win:     1  percentage:  0.33  odds:  3.00
#        >=3 goals difference in win:     0  percentage:  0.00  odds:   inf
#
#  23:  d.pts:     1    win:     0   X:     0   loss:     1
#                percentages     win:  0.00   X:  0.00   loss:  1.00   1X:  0.00   X2:  1.00
#                odds            win:   inf   X:   inf   loss:  1.00   1X:   inf   X2:  1.00
#        >=2 goals difference in win:     0  percentage:  0.00  odds:   inf
#        >=3 goals difference in win:     0  percentage:  0.00  odds:   inf
#
#  24:  d.pts:     1    win:     0   X:     0   loss:     1
#                percentages     win:  0.00   X:  0.00   loss:  1.00   1X:  0.00   X2:  1.00
#                odds            win:   inf   X:   inf   loss:  1.00   1X:   inf   X2:  1.00
#        >=2 goals difference in win:     0  percentage:  0.00  odds:   inf
#        >=3 goals difference in win:     0  percentage:  0.00  odds:   inf
#
#  25:  d.pts:     1    win:     0   X:     0   loss:     1
#                percentages     win:  0.00   X:  0.00   loss:  1.00   1X:  0.00   X2:  1.00
#                odds            win:   inf   X:   inf   loss:  1.00   1X:   inf   X2:  1.00
#        >=2 goals difference in win:     0  percentage:  0.00  odds:   inf
#        >=3 goals difference in win:     0  percentage:  0.00  odds:   inf
#
#  26:  d.pts:     1    win:     0   X:     0   loss:     1
#                percentages     win:  0.00   X:  0.00   loss:  1.00   1X:  0.00   X2:  1.00
#                odds            win:   inf   X:   inf   loss:  1.00   1X:   inf   X2:  1.00
#        >=2 goals difference in win:     0  percentage:  0.00  odds:   inf
#        >=3 goals difference in win:     0  percentage:  0.00  odds:   inf
#
#  27:  d.pts:     0    win:     0   X:     0   loss:     0
#                percentages     win:   nan   X:   nan   loss:   nan   1X:   nan   X2:   nan
#                odds            win:   nan   X:   nan   loss:   nan   1X:   nan   X2:   nan
#        >=2 goals difference in win:     0  percentage:   nan  odds:   nan
#        >=3 goals difference in win:     0  percentage:   nan  odds:   nan
#
#  28:  d.pts:     0    win:     0   X:     0   loss:     0
#                percentages     win:   nan   X:   nan   loss:   nan   1X:   nan   X2:   nan
#                odds            win:   nan   X:   nan   loss:   nan   1X:   nan   X2:   nan
#        >=2 goals difference in win:     0  percentage:   nan  odds:   nan
#        >=3 goals difference in win:     0  percentage:   nan  odds:   nan
#
#  29:  d.pts:     0    win:     0   X:     0   loss:     0
#                percentages     win:   nan   X:   nan   loss:   nan   1X:   nan   X2:   nan
#                odds            win:   nan   X:   nan   loss:   nan   1X:   nan   X2:   nan
#        >=2 goals difference in win:     0  percentage:   nan  odds:   nan
#        >=3 goals difference in win:     0  percentage:   nan  odds:   nan
#
#  30:  d.pts:     0    win:     0   X:     0   loss:     0
#                percentages     win:   nan   X:   nan   loss:   nan   1X:   nan   X2:   nan
#                odds            win:   nan   X:   nan   loss:   nan   1X:   nan   X2:   nan
#        >=2 goals difference in win:     0  percentage:   nan  odds:   nan
#        >=3 goals difference in win:     0  percentage:   nan  odds:   nan
#
#  31:  d.pts:     0    win:     0   X:     0   loss:     0
#                percentages     win:   nan   X:   nan   loss:   nan   1X:   nan   X2:   nan
#                odds            win:   nan   X:   nan   loss:   nan   1X:   nan   X2:   nan
#        >=2 goals difference in win:     0  percentage:   nan  odds:   nan
#        >=3 goals difference in win:     0  percentage:   nan  odds:   nan
#
#  32:  d.pts:     0    win:     0   X:     0   loss:     0
#                percentages     win:   nan   X:   nan   loss:   nan   1X:   nan   X2:   nan
#                odds            win:   nan   X:   nan   loss:   nan   1X:   nan   X2:   nan
#        >=2 goals difference in win:     0  percentage:   nan  odds:   nan
#        >=3 goals difference in win:     0  percentage:   nan  odds:   nan
#
#  33:  d.pts:     0    win:     0   X:     0   loss:     0
#                percentages     win:   nan   X:   nan   loss:   nan   1X:   nan   X2:   nan
#                odds            win:   nan   X:   nan   loss:   nan   1X:   nan   X2:   nan
#        >=2 goals difference in win:     0  percentage:   nan  odds:   nan
#        >=3 goals difference in win:     0  percentage:   nan  odds:   nan
#
#  34:  d.pts:     0    win:     0   X:     0   loss:     0
#                percentages     win:   nan   X:   nan   loss:   nan   1X:   nan   X2:   nan
#                odds            win:   nan   X:   nan   loss:   nan   1X:   nan   X2:   nan
#        >=2 goals difference in win:     0  percentage:   nan  odds:   nan
#        >=3 goals difference in win:     0  percentage:   nan  odds:   nan
# /Users/possanner/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:88: RuntimeWarning: invalid value encountered in double_scalars
# /Users/possanner/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:89: RuntimeWarning: invalid value encountered in double_scalars
# /Users/possanner/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:90: RuntimeWarning: invalid value encountered in double_scalars
# /Users/possanner/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:91: RuntimeWarning: invalid value encountered in double_scalars
# /Users/possanner/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:89: RuntimeWarning: divide by zero encountered in double_scalars
# /Users/possanner/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:90: RuntimeWarning: divide by zero encountered in double_scalars
# /Users/possanner/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:91: RuntimeWarning: divide by zero encountered in double_scalars
